# %% [markdown]
# ### This jupyter notebook is for the experiment 5 `PI-Curve` section

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 20 Degrees
current_A = np.array([ 15, 15.5, 16, 16.5, 17, 17.5, 18, 18.5, 19, 19.5, 20, 20.5, 21, 21.5, 22, 22.5, 23, 23.5, 24, 24.5, 25, 25.5, 26 ])  # Injection current (A)
power_W = np.array([0.026, 0.028, 0.031, 0.034, 0.038, 0.043, 0.051, 0.067, 0.112, 0.243, 0.401, 0.565, 0.738, 0.901, 1.086, 1.25, 1.43, 1.601, 1.762, 1.936, 2.103, 2.275, 2.45])  # Output power (W)

# %%
# 30 Degrees
current_A = np.array([17, 17.5, 18, 18.5, 19, 19.5, 20, 20.5, 21, 21.5, 22, 22.5, 23, 23.5, 24, 24.5, 25, 25.5, 26, 26.5, 27, 27.5, 28])  # Injection current (A)
power_W = np.array([0.028, 0.03, 0.032, 0.035, 0.038, 0.042, 0.048, 0.057, 0.075, 0.127, 0.258, 0.422, 0.59, 0.75, 0.927, 1.094, 1.257, 1.425, 1.6, 1.765, 1.934, 2.096, 2.269])  # Output power (W)

# %%
# 40 Degrees
current_A = np.array([20, 20.5, 21, 21.5, 22, 22.5, 23, 23.5, 24, 24.5, 25, 25.5, 26, 26.5, 27, 27.5, 28, 28.5, 29, 29.5, 30, 30.5, 31])  # Injection current (A)
power_W = np.array([0.033, 0.035, 0.038, 0.041, 0.045, 0.05, 0.057, 0.069, 0.099, 0.181, 0.33, 0.48, 0.651, 0.8, 0.952, 1.108, 1.263, 1.43, 1.58, 1.74, 1.906, 2.023, 2.189])

# %%
x_temp= np.array([20, 25, 30, 35, 40])
y_wave= np.array([0.625, 0.408, 0.267, 0.191, 0.1375])

# %%
# Create figure and axis
fig, ax = plt.subplots()

# Plot data
ax.plot(current_A, power_W, marker='o')

# Set title and labels
ax.set_title('PI Curve')
ax.set_xlabel('Injection Current (A)')
ax.set_ylabel('Output Power (W)')

# Grid and ticks
ax.grid(True)
ax.set_xticks(np.arange(0, 30, 0))
ax.set_yticks(np.arange(0, 5, 0.5))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[18], line 14
#      12 # Grid and ticks
#      13 ax.grid(True)
# ---> 14 ax.set_xticks(np.arange(0, 30, 0))
#      15 ax.set_yticks(np.arange(0, 5, 0.5))
#
# ZeroDivisionError: division by zero

# %%
# Show plot
plt.show()

# %%
# Create figure and axis for temp vs wavelength
fig, ax = plt.subplots()

# Plot data
ax.plot(x_temp, y_wave, marker='o')

# Set title and labels
ax.set_title('Temperature vs Wavelength')
ax.set_xlabel('Temperature (°C)')
ax.set_ylabel('Emission Wavelength (λ)')

# Grid and ticks
ax.grid(True)
ax.set_xticks(np.arange(0, 30, 0))
ax.set_yticks(np.arange(0, 5, 0.5))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[21], line 14
#      12 # Grid and ticks
#      13 ax.grid(True)
# ---> 14 ax.set_xticks(np.arange(0, 30, 0))
#      15 ax.set_yticks(np.arange(0, 5, 0.5))
#
# ZeroDivisionError: division by zero
