# %%
import matplotlib.pyplot as plt

# Data
temperature = [20.0, 20.1, 20.2, 20.3, 20.4, 20.5, 20.6, 20.7, 20.8]  # Temperature in °C
# delta_lambda = [0, 0, 1.56e14, 4.44e14, 7.44e14, 1.07e15, 1.22e15, 1.55e15, 1.84e15]  # Δλ in nm
delta_lambda = [0, 0, 1.21E-14, 1.77E-14, 2.80E-14, 3.88E-14, 5.04E-14, 5.60E-14, 6.77E-14, 7.80E-14]  # Δλ in nm

# Create the plot
plt.figure(figsize=(8, 6))  # Set figure size
plt.plot(temperature, delta_lambda, marker='o', linestyle='-', color='b', label='Δλ vs Temperature')

# Add labels and title
plt.xlabel('Temperature (°C)', fontsize=12)
plt.ylabel('Δλ (nm)', fontsize=12)
plt.title('Wavelength Change (Δλ) vs Temperature', fontsize=14)

# Add grid
plt.grid(True, linestyle='--', alpha=0.6)

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 10
#       8 # Create the plot
#       9 plt.figure(figsize=(8, 6))  # Set figure size
# ---> 10 plt.plot(temperature, delta_lambda, marker='o', linestyle='-', color='b', label='Δλ vs Temperature')
#      12 # Add labels and title
#      13 plt.xlabel('Temperature (°C)', fontsize=12)
#
# File c:\Software\envs\LoadProfile_Generator2\lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
import matplotlib.pyplot as plt

# Data
temperature = [20.0, 20.1, 20.2, 20.3, 20.4, 20.5, 20.6, 20.7, 20.8]  # Temperature in °C
delta_lambda = [0,  1.21E-14, 1.77E-14, 2.80E-14, 3.88E-14, 5.04E-14, 5.60E-14, 6.77E-14, 7.80E-14]  # Δλ in nm

# Create the plot
plt.figure(figsize=(8, 6))  # Set figure size
plt.plot(temperature, delta_lambda, marker='o', linestyle='-', color='b', label='Δλ vs Temperature')

# Add labels and title
plt.xlabel('Temperature (°C)', fontsize=12)
plt.ylabel('Δλ (nm)', fontsize=12)
plt.title('Wavelength Change (Δλ) vs Temperature', fontsize=14)

# Add grid
plt.grid(True, linestyle='--', alpha=0.6)

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_with_slope(temp, delta_lambda):
    # Convert lists to numpy arrays for easier calculation
    temp = np.array(temp)
    delta_lambda = np.array(delta_lambda)
    
    # Calculate the slope using numpy's polyfit
    # polyfit returns coefficients of the line of best fit (slope is the first coefficient)
    slope, intercept = np.polyfit(temp, delta_lambda, 1)
    
    # Create the line of best fit
    line_of_best_fit = slope * temp + intercept
    
    # Create the plot
    plt.figure(figsize=(8, 6))
    
    # Plot original data points
    plt.plot(temp, delta_lambda, 'o', label='Data Points')
    
    # Plot line of best fit
    plt.plot(temp, line_of_best_fit, 'r--', label=f'Slope = {slope:.2e} nm/°C')
    
    # Add labels and title
    plt.xlabel('Temperature (°C)', fontsize=12)
    plt.ylabel('Δλ (nm)', fontsize=12)
    plt.title('Wavelength Change (Δλ) vs Temperature with Slope', fontsize=14)
    
    # Add grid
    plt.grid(True, linestyle='--', alpha=0.6)
    
    # Add legend
    plt.legend()
    
    # Show the plot
    plt.show()
    
    return slope

# Data
temperature = [20.0, 20.1, 20.2, 20.3, 20.4, 20.5, 20.6, 20.7]  # Temperature in °C
delta_lambda = [1.21E-14, 1.77E-14, 2.80E-14, 3.88E-14, 5.04E-14, 5.60E-14, 6.77E-14, 7.80E-14]  # Δλ in nm

# Call the function and get the slope
slope = plot_with_slope(temperature, delta_lambda)
print(f"\nThe slope of the line is: {slope:.2e} nm/°C")
# Out:
# The slope of the line is: 9.61e-14 nm/°C
